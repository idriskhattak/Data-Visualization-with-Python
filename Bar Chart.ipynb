# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
year=[2000,2001,2002,2003,2004,2005]
oranges=[10,5,12,16,17,18]
mangoes=[5,2,7,9,5,3,]

# %%
plt.bar(year,oranges)
# Out:
# <BarContainer object of 6 artists>

# %%
#we can plot line plots and bar chart together to see the trend adn relation between the data'
plt.title('Number of oranges produce per year(TON)')
plt.xlabel('Years')
plt.ylabel('Oranges(Per TON)')
plt.bar(year,oranges)
plt.plot(year,oranges,'o--r')

# %%
tips_df=sns.load_dataset("tips")

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#average bill per day using plt plot
bill_avg=tips_df.groupby('day')[['total_bill']].mean()

# %%
bill_avg
# Out:
#       total_bill
# day
# Thur   17.682742
# Fri    17.151579
# Sat    20.441379
# Sun    21.410000

# %%
plt.bar(bill_avg.index,bill_avg.total_bill)
# Out:
# <BarContainer object of 4 artists>

# %%
#we can do the same thing in much better way by using seaborn sns
sns.barplot(x='day', y='total_bill', data=tips_df);

# %%
sns.barplot(x='day', y='total_bill',hue='sex', data=tips_df);
